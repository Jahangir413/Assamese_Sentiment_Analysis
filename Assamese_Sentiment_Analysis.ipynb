# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU memory growth enabled.")
    except RuntimeError as e:
        print("Memory growth setting failed:", e)
else:
    print("No GPU detected — using CPU (slower).")
# Out:
# GPU memory growth enabled.

# %%
# !pip install -q scikit-learn

# %%
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split
from sklearn.utils import resample, shuffle
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Bidirectional, Dense, SpatialDropout1D, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
data_path = "/content/drive/MyDrive/Assamese/Assamese_Sentiments_70k.csv"
data = pd.read_csv(data_path)

# Validate dataset columns
assert 'Assamese Text' in data.columns and 'Sentiments' in data.columns, \
    "Dataset must have 'Assamese Text' and 'Sentiments' columns."

# %%
def clean_text(text):
    text = re.sub('[^\u0980-\u09ff\s]', '', str(text))  # Keep Assamese chars
    text = re.sub('\s+', ' ', text).strip()             # Remove extra spaces
    text = re.sub(r'(.)\1{2,}', r'\1\1', text)          # Reduce repeated chars
    text = ' '.join([w for w in text.split() if len(w) > 1])  # Remove single letters
    return text

data['Assamese Text'] = data['Assamese Text'].apply(clean_text)
data = data[data['Assamese Text'].str.strip() != '']

# %%
max_count = data['Sentiments'].value_counts().max()

balanced_data = pd.concat([
    resample(group, replace=True, n_samples=max_count, random_state=42)
    for _, group in data.groupby('Sentiments')
]).reset_index(drop=True)

balanced_data = shuffle(balanced_data, random_state=42)

# %%
train, test = train_test_split(
    balanced_data,
    test_size=0.2,
    random_state=42,
    stratify=balanced_data['Sentiments']
)

# %%
max_features = 30000  # vocabulary size
lengths = train['Assamese Text'].apply(lambda x: len(x.split()))
maxlen = int(lengths.quantile(0.95))  # 95% length coverage

tokenizer = Tokenizer(num_words=max_features, split=' ')
tokenizer.fit_on_texts(train['Assamese Text'].values)

X_train = pad_sequences(tokenizer.texts_to_sequences(train['Assamese Text']), maxlen=maxlen)
X_test = pad_sequences(tokenizer.texts_to_sequences(test['Assamese Text']), maxlen=maxlen)

# %%
label_order = ['Negative', 'Positive', 'Neutral']
Y_train = pd.get_dummies(train['Sentiments'])[label_order].values
Y_test = pd.get_dummies(test['Sentiments'])[label_order].values

# Convert to float32
X_train = np.array(X_train, dtype=np.float32)
Y_train = np.array(Y_train, dtype=np.float32)
X_test = np.array(X_test, dtype=np.float32)
Y_test = np.array(Y_test, dtype=np.float32)

# Safety check
assert X_train.shape[0] > 0 and Y_train.shape[0] > 0, "Training data is empty!"
assert X_test.shape[0] > 0 and Y_test.shape[0] > 0, "Testing data is empty!"

print(f"Train shapes: X={X_train.shape}, Y={Y_train.shape}")
print(f"Test shapes: X={X_test.shape}, Y={Y_test.shape}")
# Out:
# Train shapes: X=(103824, 18), Y=(103824, 3)
# Test shapes: X=(25956, 18), Y=(25956, 3)

# %%
embed_dim = 200

model = Sequential([
    Embedding(input_dim=max_features, output_dim=embed_dim, input_length=maxlen),
    SpatialDropout1D(0.4),
    Bidirectional(LSTM(256, return_sequences=True, dropout=0.4, recurrent_dropout=0.4)),
    Bidirectional(LSTM(128, dropout=0.4, recurrent_dropout=0.4)),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')
])

model.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout1d               │ ?                      │             0 │
# │ (SpatialDropout1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
checkpoint_path = "/content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras"

checkpoint = ModelCheckpoint(
    filepath=checkpoint_path,
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

early_stop = EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)

history = model.fit(
    X_train, Y_train,
    epochs=45,
    batch_size=128,
    validation_split=0.2,
    callbacks=[early_stop, checkpoint],
    verbose=1
)
# Out:
# Epoch 1/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.3556 - loss: 1.0899
# Epoch 1: val_accuracy improved from -inf to 0.51360, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 187s 258ms/step - accuracy: 0.3557 - loss: 1.0899 - val_accuracy: 0.5136 - val_loss: 0.9453
# Epoch 2/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.5713 - loss: 0.8668
# Epoch 2: val_accuracy improved from 0.51360 to 0.64286, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 164s 253ms/step - accuracy: 0.5714 - loss: 0.8668 - val_accuracy: 0.6429 - val_loss: 0.7647
# Epoch 3/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.7156 - loss: 0.6375
# Epoch 3: val_accuracy improved from 0.64286 to 0.69174, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 162s 250ms/step - accuracy: 0.7156 - loss: 0.6375 - val_accuracy: 0.6917 - val_loss: 0.6919
# Epoch 4/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.7786 - loss: 0.5028
# Epoch 4: val_accuracy improved from 0.69174 to 0.72796, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 167s 257ms/step - accuracy: 0.7786 - loss: 0.5028 - val_accuracy: 0.7280 - val_loss: 0.6438
# Epoch 5/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.8154 - loss: 0.4197
# Epoch 5: val_accuracy improved from 0.72796 to 0.74784, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 200s 253ms/step - accuracy: 0.8154 - loss: 0.4197 - val_accuracy: 0.7478 - val_loss: 0.6195
# Epoch 6/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.8358 - loss: 0.3684
# Epoch 6: val_accuracy improved from 0.74784 to 0.76085, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 197s 245ms/step - accuracy: 0.8358 - loss: 0.3684 - val_accuracy: 0.7608 - val_loss: 0.6421
# Epoch 7/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.8532 - loss: 0.3331
# Epoch 7: val_accuracy improved from 0.76085 to 0.76740, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 207s 253ms/step - accuracy: 0.8532 - loss: 0.3331 - val_accuracy: 0.7674 - val_loss: 0.6679
# Epoch 8/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.8660 - loss: 0.2989
# Epoch 8: val_accuracy improved from 0.76740 to 0.78286, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 200s 251ms/step - accuracy: 0.8660 - loss: 0.2989 - val_accuracy: 0.7829 - val_loss: 0.6498
# Epoch 9/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.8749 - loss: 0.2816
# Epoch 9: val_accuracy improved from 0.78286 to 0.78724, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 203s 253ms/step - accuracy: 0.8749 - loss: 0.2816 - val_accuracy: 0.7872 - val_loss: 0.6499
# Epoch 10/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.8856 - loss: 0.2608
# Epoch 10: val_accuracy improved from 0.78724 to 0.79133, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 197s 246ms/step - accuracy: 0.8856 - loss: 0.2608 - val_accuracy: 0.7913 - val_loss: 0.7066
# Epoch 11/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.8914 - loss: 0.2452
# Epoch 11: val_accuracy improved from 0.79133 to 0.79711, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 205s 250ms/step - accuracy: 0.8914 - loss: 0.2452 - val_accuracy: 0.7971 - val_loss: 0.7279
# Epoch 12/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.8970 - loss: 0.2337
# Epoch 12: val_accuracy improved from 0.79711 to 0.80212, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 201s 249ms/step - accuracy: 0.8970 - loss: 0.2337 - val_accuracy: 0.8021 - val_loss: 0.7311
# Epoch 13/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9042 - loss: 0.2187
# Epoch 13: val_accuracy improved from 0.80212 to 0.80352, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 203s 251ms/step - accuracy: 0.9042 - loss: 0.2188 - val_accuracy: 0.8035 - val_loss: 0.7387
# Epoch 14/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9095 - loss: 0.2059
# Epoch 14: val_accuracy improved from 0.80352 to 0.80876, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 196s 242ms/step - accuracy: 0.9095 - loss: 0.2059 - val_accuracy: 0.8088 - val_loss: 0.7338
# Epoch 15/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9118 - loss: 0.2010
# Epoch 15: val_accuracy improved from 0.80876 to 0.81406, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 204s 246ms/step - accuracy: 0.9118 - loss: 0.2010 - val_accuracy: 0.8141 - val_loss: 0.7818
# Epoch 16/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9194 - loss: 0.1874
# Epoch 16: val_accuracy improved from 0.81406 to 0.81474, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 202s 246ms/step - accuracy: 0.9194 - loss: 0.1874 - val_accuracy: 0.8147 - val_loss: 0.8164
# Epoch 17/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9244 - loss: 0.1780
# Epoch 17: val_accuracy did not improve from 0.81474
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 203s 247ms/step - accuracy: 0.9244 - loss: 0.1780 - val_accuracy: 0.8135 - val_loss: 0.8607
# Epoch 18/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9239 - loss: 0.1739
# Epoch 18: val_accuracy improved from 0.81474 to 0.81965, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 204s 251ms/step - accuracy: 0.9239 - loss: 0.1739 - val_accuracy: 0.8196 - val_loss: 0.8443
# Epoch 19/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9300 - loss: 0.1650
# Epoch 19: val_accuracy improved from 0.81965 to 0.82336, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 203s 253ms/step - accuracy: 0.9300 - loss: 0.1650 - val_accuracy: 0.8234 - val_loss: 0.8281
# Epoch 20/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.9332 - loss: 0.1568
# Epoch 20: val_accuracy improved from 0.82336 to 0.82398, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 199s 248ms/step - accuracy: 0.9332 - loss: 0.1568 - val_accuracy: 0.8240 - val_loss: 0.8587
# Epoch 21/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9364 - loss: 0.1491
# Epoch 21: val_accuracy improved from 0.82398 to 0.82548, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 201s 246ms/step - accuracy: 0.9364 - loss: 0.1491 - val_accuracy: 0.8255 - val_loss: 0.8627
# Epoch 22/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.9368 - loss: 0.1450
# Epoch 22: val_accuracy improved from 0.82548 to 0.82812, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 166s 255ms/step - accuracy: 0.9368 - loss: 0.1450 - val_accuracy: 0.8281 - val_loss: 0.9094
# Epoch 23/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.9421 - loss: 0.1371
# Epoch 23: val_accuracy improved from 0.82812 to 0.82856, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 196s 246ms/step - accuracy: 0.9421 - loss: 0.1371 - val_accuracy: 0.8286 - val_loss: 0.9150
# Epoch 24/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.9408 - loss: 0.1383
# Epoch 24: val_accuracy improved from 0.82856 to 0.82889, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 201s 245ms/step - accuracy: 0.9408 - loss: 0.1383 - val_accuracy: 0.8289 - val_loss: 0.8862
# Epoch 25/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9448 - loss: 0.1313
# Epoch 25: val_accuracy improved from 0.82889 to 0.83328, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 202s 244ms/step - accuracy: 0.9448 - loss: 0.1313 - val_accuracy: 0.8333 - val_loss: 0.9745
# Epoch 26/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9462 - loss: 0.1277
# Epoch 26: val_accuracy did not improve from 0.83328
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 202s 244ms/step - accuracy: 0.9462 - loss: 0.1277 - val_accuracy: 0.8313 - val_loss: 0.9590
# Epoch 27/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9468 - loss: 0.1254
# Epoch 27: val_accuracy did not improve from 0.83328
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 206s 250ms/step - accuracy: 0.9468 - loss: 0.1254 - val_accuracy: 0.8319 - val_loss: 0.9690
# Epoch 28/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9501 - loss: 0.1167
# Epoch 28: val_accuracy did not improve from 0.83328
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 203s 253ms/step - accuracy: 0.9501 - loss: 0.1167 - val_accuracy: 0.8329 - val_loss: 1.0494
# Epoch 29/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9515 - loss: 0.1143
# Epoch 29: val_accuracy improved from 0.83328 to 0.83583, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 203s 254ms/step - accuracy: 0.9515 - loss: 0.1143 - val_accuracy: 0.8358 - val_loss: 1.0112
# Epoch 30/45
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.9520 - loss: 0.1132
# Epoch 30: val_accuracy improved from 0.83583 to 0.83761, saving model to /content/drive/MyDrive/Assamese_Sentiment/best_model_optimized.keras
# 649/649 ━━━━━━━━━━━━━━━━━━━━ 167s 258ms/step - accuracy: 0.9520 - loss: 0.1132 - val_accuracy: 0.8376 - val_loss: 1.0652

# %%
Y_pred = np.argmax(model.predict(X_test, batch_size=128), axis=-1)
Y_true = np.argmax(Y_test, axis=-1)

print("\nConfusion Matrix:\n", confusion_matrix(Y_true, Y_pred))
print("\nClassification Report:\n", classification_report(Y_true, Y_pred, target_names=label_order, digits=4))
# Out:
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 11s 48ms/step
#
# Confusion Matrix:
#  [[7721  205  726]
#  [ 812 5476 2364]
#  [1191 1604 5857]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#     Negative     0.7940    0.8924    0.8403      8652
#     Positive     0.7517    0.6329    0.6872      8652
#      Neutral     0.6546    0.6770    0.6656      8652
#
#     accuracy                         0.7341     25956
#    macro avg     0.7334    0.7341    0.7310     25956
# weighted avg     0.7334    0.7341    0.7310     25956
